# %%
import pandas as pd
import datetime
start_date = datetime.date(1950, 1, 1)

# %%
cards = Card.objects.all()
print(cards.count())

# %%
cards.filter(creator_person__date_of_death__lte=start_date).count()

# %%
persons = Person.objects.all()

# %%
data = []
for x in persons.filter(date_of_death__lte=start_date):
    created_cards = x.created_by_person.all().count()
    item = ([x, x.date_of_death, created_cards])
    data.append(item)

# %%
df = pd.DataFrame(data, columns=['künstler', 'gestorben', 'karten'])

# %%
df.to_excel('kuenstler_tot.xlsx')

# %%
data = []
for x in cards.filter(creator_person__date_of_death__lte=start_date):
    item = (x, x.img_front, x.img_back, "|".join([f"{y.name} *{y.date_of_death}" for y in x.creator_person.all()]))
    data.append(item)
df = pd.DataFrame(data, columns=['karte', 'bildseite','adressseite', 'künstler'])

# %%
df.to_excel('karten_kuenstler.xlsx')

# %%
hansi = [x['mentioned_person'] for x in Card.objects.values('mentioned_person')]

# %%
hansi
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
Person.objects.all().count()
# Out:
# 134
